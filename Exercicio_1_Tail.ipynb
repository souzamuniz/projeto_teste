# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('data.csv')
dados.head()
# Out:
#         Nome  Idade  Anos-de-Experiencia-na-Area
# 0  Guilherme     17                            1
# 1      Jânio     19                            1
# 2   Anderson     24                            2
# 3      Lucas     23                            4
# 4       Sara     23                            2

# %%
dados = dados.rename(columns = {'Anos-de-Experiencia-na-Area':'Anos_de_exp'})

# %%
dados.query('Idade>20')
# Out:
#           Nome  Idade  Anos_de_exp
# 2     Anderson     24            2
# 3        Lucas     23            4
# 4         Sara     23            2
# 5     Angelina     23            3
# 6        Bruno     23            4
# 7        Pedro     27            5
# 8   Ana Flávia     30            9
# 12    Leonardo     21            3
# 13        Igor     25            3
# 14      Amanda     25            4
# 15     Jéssica     24            5

# %%
dados.query('Anos_de_exp>4')
# Out:
#           Nome  Idade  Anos_de_exp
# 7        Pedro     27            5
# 8   Ana Flávia     30            9
# 15     Jéssica     24            5

# %%
print(dados.sort_values(by = ['Idade']))

dados.sort_values(by = ['Anos_de_exp'])
# Out:
#           Nome  Idade  Anos_de_exp
# 0    Guilherme     17            1
# 1        Jânio     19            1
# 9    Ana Maria     19            2
# 10   Ana Luiza     20            1
# 11     Matheus     20            1
# 12    Leonardo     21            3
# 3        Lucas     23            4
# 4         Sara     23            2
# 5     Angelina     23            3
# 6        Bruno     23            4
# 2     Anderson     24            2
# 15     Jéssica     24            5
# 13        Igor     25            3
# 14      Amanda     25            4
# 7        Pedro     27            5
# 8   Ana Flávia     30            9
#           Nome  Idade  Anos_de_exp
# 0    Guilherme     17            1
# 1        Jânio     19            1
# 10   Ana Luiza     20            1
# 11     Matheus     20            1
# 2     Anderson     24            2
# 4         Sara     23            2
# 9    Ana Maria     19            2
# 5     Angelina     23            3
# 12    Leonardo     21            3
# ...

# %%
dados.plot.bar(x = 'Nome', y = 'Idade', rot = 0, figsize = (20,5));

# %%
dados.plot.bar(x = 'Nome', y = 'Anos_de_exp', rot = 0, figsize = (20,5));

# %%
dados.plot(x = 'Nome', y = 'Anos_de_exp',figsize = (20,5));

# %%
x = dados.plot(x = 'Nome', y = 'Idade',figsize = (20,5));

# %%
x = dados.plot.scatter(x = 'Nome', y = 'Idade',figsize = (20,5));

# %%
dados.hist('Idade');

# %%
dados.hist('Anos_de_exp');
